# %% [markdown]
# Question 1:
#
# a. cp -r /cours/a23_bcm3553_bcm6010-a/cours/TP6/* Documents/BCM3553/TP6
# ln -s /cours/a23_bcm3553_bcm6010-a/cours/TP6 Documents/BCM3553/TP6
# R : setwd("~/Documents/BCM3553/TP6")
#
# b. /apps_rh8/Local_rh8/R/R-4.3.1/lib64/R/library/msdata/microtofq
#
# c. Il s'agit du MM14 et je le vois car plusieurs parametres comme lowMz et highMz =0. de plus, le parametre startTimeStamp est NA (vide).
#
# d. Les valeurs de lowMz et highMz signifie respectivement les plus basse et plus haute valeur de masse(m)/charge(z) trouvees lors de l'analyse du spectre de masse des peptides de MM8.
#
# Question 2:
#
# a.Non, les deux fichiers ne me donnent pas la meme information : Tandem met en avant les identifiants des sequences peptidiques et leur masse experimentales tandis que Mascot refere a la proteine et a l'organisme contentant ce peptide.
#
# b. La masse experimentale de ce peptide est de 15.9949. J' ai trouve l'information en allant chercher dans le fichier Tandem et en effectuant une recherche via CTR F de la sequence du peptide.
#
# c. il appartient a la proteine cognate 4 (Hsc 70-4) et l'organisme correspondant est Manduca sexta (Tobacco hawkmoth), (Tobacco hornworm).
#
# d. Il s'agit de la trypsine. Cette enzyme est une peptidasea serine qui hydrolyse a cote d'une lysine ou d'une arginine.
#
# Question 3:
#
# a. le spectre 2 a 1012 peaks ionique
#
# b. Le spectre le plus a gauche a le plus haut signal et celui a l'extremite droite a le plus petit ratio masse/charge.
#
# c. iTRAQ permet de comparer, grace a la technique de superposition, des donnees de differents echantillons de spectrometrie de masse.
#
# Question 4:
#
# a. 5 echantillons
#
# b. Il s'agit de ALBU_BOVIN qui suit ce schema.
#
# c. On ne semble plus s'interesser a "TRYP_PIG" car peut etre qu'il ne faisait aucune distinction entre les 5 rapporteurs : soit il etait absent ou present dans le 5. "ECA" apporte une vraie divergence et a divers niveaux pour les 5 rapporteurs ce qui permet de les comperer plus aisement.
#
# d. Il s'agit de teur-129.
#
# e. On ne peut le confirmer que pour le teur -131 car c'est celui premierement qui a le plus haut signal et deuxiemement car en regardant le dernier graphique, on constate qu'il n'y a que 2 signaux. Ceci signifie que les autres signaux emanant des autres rapporteurs sont consideres comme similaires contrairement a celui du 131 qui est superieur et donc distinguable.
#
# Question 5:
#
# a. il le faut car il s'agit d'une feuille de calcul et ainsi lorsque les donnees sont extraites sous forme de texte, elles sont comme collees les unes aux autres ce qui rend impossible la tache de les analyser. Avec "sep="\t" ", les colonnes seront separees par une tabulation.
#
# b.
#
# c. il y en avait 10.
#
#
# Question 6:
#
# a. il y a 25 baits et ainsi le reste des proteines devraient correspondre au nombre de "Prey" soit 279. Par exemple en ce qui concerne les differents baits, on a : NSP 7, NSP 8 et NSP 9.
#
# b. LA fonction "unique" sert ici extraire les donnees de la colonne "Bait_COVID.19" contenu dans "SARS_massSpec" pour les mettre dans "SARS_protein_list".
#
# c. min/maxGSsize correspondent respectivement a la taille minimale et maximale des ensembles des genes a considerer dans l'analyse.
# Le format correspond a matrice de sortie est une liste de termes GO avec sa valeur p d'enrichissement et les gènes impliqués.
#
# d. Avant le retrait il y en avait 7398 et apres 1361 donc, il y a 6037 lignes qui ont ete enleve.
#
# e. Apres le retrait il en reste 1032 donc il y a 329 lignes qui ont ete enleve.
# J'ai obtenu les informations des 2 dernieres questions avec la commande:
# print(nrow(enriched_GOs_master_table))
#
# f. La base de donnees est : org.Hs.eg.db
#
# g. « Glycoprotein metabolic processing »  MF
#  « Golgi apparatus subcompartment » --> BP
#   « DNA replication initiation » --> BP
#   « Endopeptidase activity » MF
#
# h. Il y en a 220. par exemple: polysaccharide biosynthetic process
#
# i. Il y en a 1 : Nuclear pore
#
# j. Il s'agit de GOCC_ENDOPLASMIC_RETICULUM_LUMEN (GO de type CC), il appartient au ORF8, il a 16 Prey (par exemple: endoplasmique reticulum lumen) et sa valeur de significativite est : 13,899994.
#
# Question 7:
#
# a. La commande : while (length(SARS_genes_count) <= 25) sert a dire que tant que la condition (la longueur de la variable SARS_genes_count est inferieur a 25) est vraie, alors la boucle continue.
#
# b. on la transforme pour que la creation de la heatmap soit plus simple et qu'il n' y ait pas de petites valeurs mais plutot des grandes : en faisant le log 10.
#
# c. rownames_matrix <- GO_enrich_matrix[,1] --> extrait les valeurs de la premiere colonne de GO_enrich_matrix et la met dans rownames_matrix.
# GO_enrich_matrix <- GO_enrich_matrix[,-c(1)] --> a pour but de supprimer la premiere colonne de GO_enrich_matrix.
#
# d. il y en a 256.
#
# e. C'est "cellwidth" qui me permet dans pheatmap de vhanger la largeur des carres.
#
# Question 8 :
#
# a. Oui il s'agit bien de ORF8 avec l' endoplasmic reticulum lumen. C' est normal car c'est lui qui a avait la plus haute p-value transformee.
#
# b. Il fait du sens car ce qui lui est identifie est le RNA Splicing et c'est ce avec quoi il a la plus haute p-value transforme.
#
# c. C'est le cas car leur p-value transformee est plus importante que celle de NSP9.
#
# d. Le NSP9 permettrait de former un complexe Cul2-RING ubiquitine ligase et donc que sa fonction serait ubiquitine ligase.
#
# e. C'est le cas car les fonctions qui leur sont associees ne leur correspondent que peu.
#
# Question 9 :
#
# a. L'information contenue dans cette matrice est : le nombre de proteines (de differents genes) presentent dans certains organes. Il y aainsi une association entre ces proteines et les differents organes proposes.
#
# b. Le code applique la fonction log10 sur toutes les lignes des colonnes a partir de la quatrieme: tous les nombres subiront ainsi le log10.
#
# Question 10 :
#
# a. Le graphique permet de classer par ordre decroissant de log10 (p-value) des proteines presentes dans les differents tissus/organes.
#
# b. D'apres la figure 2 de l'article cite ci-bas, les poumons sont bien l'organe qui presente le plus de proteines mais pour le reste de la liste, il y a beaucoup de differences: le cerveau par exemple est le 3e alors que dans notre graphique, il n'est pas le 3e (les chiffres sont differents).
#
# Citation : Zheng, B., Yuan, M., Ma, Q., Wang, S., Tan, Y., Xu, Y., Ye, J., Gao, Y., Sun, X., Yang, Z., Xu, P., Kong, L., Wu, X., & Xu, Q. (2021). Landscape of SARS-CoV-2 spike protein-interacting cells in human tissues. International immunopharmacology, 95, 107567. https://doi.org/10.1016/j.intimp.2021.107567
#
# c. Ici, aucun des resultats n'est significatif car ils ont tous une p-value superieure a 0,05.
