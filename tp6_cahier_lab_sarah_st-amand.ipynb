# %% [markdown]
# # TP6
# ## Question 1
# a) donnees ln -s /cours/a23_bcm3553_bcm6010-a/cours/TP6/data/
# Script cp cours/a23_bcm3553_bcm6010-a/cours/TP6_Processing.Rmd TP6_Processing.Rmd
# repertoire  pwd
# /home_sens/iv39426/Documents/BCM6010/TP6
#
# b)"/usr/local/R-4.3.1/lib64/R/library/msdata/microtofq"
#
# c)mz14 car le lowMz et le highMz sont 0
#
# d) lowMz : la plus petite valeur de masse et highMz la plus grande valeur de masse
#
# ## Question 2
#
# a)psms (mzidTandem) et psms(mxidMascot)ne contiennent pas exactement les memes donnees. Mascot contient plus d identifiant que Tandem et certains identifiants ne sont pas communs (Mascot.identity.threshold par exemple)
#
# b)la masse experimentale est 792.3792. L information se trouve avec la commande > head(psms(mzidTandem))[, 1:13] et sous l entete experimental MassToCharge
#
# c) Heat shock cognate 70 kDa protein (HSP70) - Echinococcus granulosus
#
# d)la peptidase est la trypsin. La trypsine coupe apres une arginine ou une lysine *sauf sous certaines exceptions source Simpson, Richard J, Fragmentation of protein using trypsin, 2006, DOI 10,1101/pdb.prot4550
#
# ## Question 3
#
# a)2921 (valeur peaks count)
#
# b) Le spectre 4 possede les plus grandes intensite. Le spectre 5 possede les plus petits ratio masse charge
#
# c)les reactifs iTRAQ permettent d identifier les proteines d un echantillon afin de pouvoir melanger plusieurs echantillon dans le meme run pour permettre la quantification relative.
#
# ## Question 4
#
# a)5 car il y a 5 lignes sur le graphique
#
# b)albumine bovine
#
# c)On ajoute ECA pour le background TRYP_pig absent
#
# d) rapporteur 129 a la plus grande concentration de BSA
#
# e)Pour les autres rapporteurs le signal est dans le background donc on ne peut pas savoir si la proteine est presente
#
# ## Question 5
#
# a)tsv veut dire tabulation separated value donc les donnees sont separees par une tabulation notee \t.
#
# b) on aurait pu utiliser C5.mf pour les voies moleculaires
#
# c)Je crois qu il y a 21 termes qu on peut chercher (soit le nombre de lignes du tableau d un GO term qu on peut trouver en ligne)
#
# ## Question 6
#
# a)Il y a 27 baits (proteines virales) et 304 prey (proteine ayant interagit)
#
# b)Pour eliminer les proteines qui sont en doubles pour s assurer de pas surevalue le nombre
#
# c)La valeur minimal GSS est le nombre de genes minimum contenu dans le gene set analyse. Cela permet d eliminer les gene set trop petit qui n offre pas de l information significative. Maximal GSS c est le nombre de genes maximum contenu dans les genes set a tester. je crois que ca permet de reduire la duree du processus et d avoir des gene set qui sont digestible. la significativite est donnee avec un q value
#
# d) a l aide la fonction dim() on peut voir que sans la filtration il y a 7398 Go term et apres la filtration il y a 1361 GO terme donc il y a 6037 lignes d enlever
#
# e)1 361 avant la filtration et 1 032 apres donc 329
#
# f)MSigDB
#
# g)glycoprotein metabolic processing : BP
#
# Golgi appartus subcompartement : CC
#
# DNA replication : BP
#
# endopeptidase activity :MF
#
# h)220 dont GOBP_POLYSACCHARIDE_BIOSYNTHETIC_PROCESS
#
# i) 1 GOCC_NUCLEAR_PORE
#
# j)Le go-term le plus significatif est ENDOPLASMIC_RETICULUM_LUMEN. Le bait est ORF8. 16 proteines prey participent a l enrichissement, dont TOR1A et le padjust est 1,258944 x 10^-14.
#
# ## Question 7
#
# a)tant que le compte et egal ou plus petit a 25 la boucle continue
#
# b)Pour faciliter la lecture
#
# c)la premiere ligne met la valeur de la premiere ligne dans rownames_matrix
# la deuxieme ligne met le reste de la matrice dans GO_enrich_matrix
# Cela nous permettra de nommer les lignes facilement
#
# d)9 couleurs
#
# e)cellwidth
#
# ## Question 8
#
# a) oui c est consistant, car endoplasmic reticulum lumen est le carre le plus fonce (representant le plus enrichi et il est dans la colonne de ORF8
#
# b) le go term le plus enrichi avec NSP12 est le RNA splicing via transesterification ca peut etre interressant car le NSP12 est une polymerase donc elle pourrait affecter l expression genique et aider l infection
#
# c)Les go term sont assez similaire. certaines proteines pourraient faire partie de plusieurs de ces GO term ce qui explique leur enrichissement
#
# d)Cette proteine pourrait servir a faire entrer les genes viraux dans le noyau des cellules eucaryotes
#
# e)les signaux pales indiquent que l enrichissement est faible. Probablement que ces proteines interagissent peu avec des proteines humaines donc l enrichissement est faible.
#
# ## Question 9
#
# a)La matrice contient les valeurs d expressions des proteines dans differents tissus
#
# b)On enleve les informations dont nous n avons pas besoin et nous transformons les valeurs en log10
#
# ## Question 10
#
# a)Les proteines interagissant avec SRAS se trouve en grande quantite dans les poumons, le foie et le coeur.
#
# b)Khreefa Z, Barbier MT, Koksal AR, Love G, Del Valle L. Pathogenesis and Mechanisms of SARS-CoV-2 Infection in the Intestine, Liver, and Pancreas. Cells. 2023 Jan 9;12(2):262. doi: 10.3390/cells12020262. PMID: 36672197; PMCID: PMC9856332.
#
# Cet article indique qu a part le poumons les sites d entrees potentiel pour le SRAS COV2 sont le foie et les intestins et le pancreas. Donc, les resultats sont assez representatifs des autres sites possibles d infections. C est tout a fait plausible que les proteines virales interagissent plus avec des sites ou l infection commence.
#
# c) les resultat sont significatifs car les barres du graphiques nous indiquent que les p values sont plus petite que 0,05
